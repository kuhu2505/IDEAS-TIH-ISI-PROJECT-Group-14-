# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Excel file
file_path = "D:\Correlation..xlsx"
df = pd.read_excel(file_path)

# Check for numeric columns only (correlation only works on numeric data)
numeric_df = df.select_dtypes(include='number')

# Compute correlation matrix
correlation_matrix = numeric_df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Generate a heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

# Title and display
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Kuhu\AppData\Local\Temp\ipykernel_18160\3423111301.py:6: SyntaxWarning: invalid escape sequence '\C'
#   file_path = "D:\Correlation..xlsx"

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Excel file
file_path = "D:\Correlation.xlsx"
df = pd.read_excel(file_path)

# Check for numeric columns only (correlation only works on numeric data)
numeric_df = df.select_dtypes(include='number')

# Compute correlation matrix
correlation_matrix = numeric_df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Generate a heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

# Title and display
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Kuhu\AppData\Local\Temp\ipykernel_18160\3544721763.py:6: SyntaxWarning: invalid escape sequence '\C'
#   file_path = "D:\Correlation.xlsx"

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the Excel file
file_path = "D:\Correlation.xlsx"
df = pd.read_excel(file_path)

# Check for numeric columns only (correlation only works on numeric data)
numeric_df = df.select_dtypes(include='number')

# Compute correlation matrix
correlation_matrix = numeric_df.corr()

# Set up the matplotlib figure
plt.figure(figsize=(12, 8))

# Generate a heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)

# Title and display
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.show()
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# <>:6: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\Kuhu\AppData\Local\Temp\ipykernel_18160\726061097.py:6: SyntaxWarning: invalid escape sequence '\C'
#   file_path = "D:\Correlation.xlsx"
