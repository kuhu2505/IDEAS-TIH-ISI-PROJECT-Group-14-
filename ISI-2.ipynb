# %%
import streamlit as st
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
import numpy as np

# %%
st.set_page_config(layout="wide")
st.title("🗳️ Electoral Performance Dashboard")

# Load metrics and original data
@st.cache_data
def load_data():
    metrics = pd.read_csv("D:/district_vote_metrics.csv")
    all_sheets = pd.read_excel("D:/District-Trend.xlsx", sheet_name=None)
    return metrics, all_sheets

metrics_df, data_dict = load_data()

# Sidebar filters
st.sidebar.header("🌟 Filter Options")
sheet_names = sorted(map(str, data_dict.keys()))
selected_ac = st.sidebar.selectbox("Select Constituency", sheet_names)

# Data for selected constituency
df = data_dict[selected_ac]
df = df.dropna(how='all').dropna(axis=1, how='all')
df_long = df.melt(id_vars=[df.columns[0]], var_name='Party-Year', value_name='VoteShare')
df_long[['Party', 'Year']] = df_long['Party-Year'].astype(str).str.extract(r'(.+)-(\d+)', expand=True)
df_long['VoteShare'] = pd.to_numeric(df_long['VoteShare'], errors='coerce')
df_long['Year'] = pd.to_numeric(df_long['Year'], errors='coerce')
df_long = df_long.dropna(subset=['VoteShare'])

party_options = sorted(df_long['Party'].dropna().unique())
selected_party = st.sidebar.selectbox("Select Party", party_options)
party_df = df_long[df_long['Party'] == selected_party]

# Metrics display
mean_vote = party_df['VoteShare'].mean()
volatility = party_df['VoteShare'].std()
st.metric("📊 Mean Vote Share (%)", f"{mean_vote:.2f}")
st.metric("📉 Volatility", f"{volatility:.2f}")

# Line Chart
st.subheader(f"📈 Vote Share Trend for {selected_party} in {selected_ac}")
fig = px.line(party_df, x="Year", y="VoteShare", markers=True, title="Vote Share Over Years")
st.plotly_chart(fig, use_container_width=True)

# Prediction Widget
st.subheader("📈 Vote Share Trend & Prediction")
if len(party_df) >= 2:
    model = LinearRegression()
    X = party_df['Year'].values.reshape(-1, 1)
    y = party_df['VoteShare'].values
    model.fit(X, y)

    future_year = st.slider("Select a future year to predict", min_value=int(party_df['Year'].min()) + 1, max_value=2030, value=2026)
    prediction = model.predict([[future_year]])[0]
    st.success(f"📌 Predicted Vote Share in {future_year}: {prediction:.2f}%")

    # Show trend line
    party_df_sorted = party_df.sort_values('Year')
    trend_line = model.predict(party_df_sorted['Year'].values.reshape(-1, 1))
    party_df_sorted['Trend'] = trend_line
    fig_pred = px.line(party_df_sorted, x="Year", y=["VoteShare", "Trend"], markers=True, title="Vote Share & Trend Line")
    st.plotly_chart(fig_pred, use_container_width=True)
else:
    st.warning("Need at least 2 data points to forecast.")

# Raw data view
with st.expander("🔍 View Raw Data"):
    st.dataframe(party_df)

# Party Comparison Table
st.subheader("📊 Party Comparison Across Constituencies")
selected_metric = st.selectbox("Choose Metric", ["MeanVoteShare", "Volatility"])
comparison_df = metrics_df.pivot(index='Constituency', columns='Party', values=selected_metric)
st.dataframe(comparison_df.style.format("{:.2f}"))

# Volatility Heatmap
st.subheader("🔥 Volatility Heatmap by Constituency and Party")
vol_df = metrics_df.pivot(index='Constituency', columns='Party', values='Volatility')
fig2, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(vol_df, annot=True, cmap="YlOrRd", fmt=".2f", ax=ax)
st.pyplot(fig2)

# Export options
st.sidebar.subheader("📄 Export Data")
excel_download = metrics_df.to_excel("D:/metrics_export.xlsx", index=False)
with open("D:/metrics_export.xlsx", "rb") as f:
    st.sidebar.download_button("Download Metrics as Excel", f, file_name="metrics_export.xlsx")

csv = metrics_df.to_csv(index=False).encode('utf-8')
st.sidebar.download_button("Download CSV", csv, file_name="metrics_export.csv", mime='text/csv')
# Out:
# 2025-07-08 23:18:54.946 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.948 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.951 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.955 No runtime found, using MemoryCacheStorageManager
# 2025-07-08 23:18:54.979 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.981 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.982 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.984 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.986 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.990 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.993 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.994 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:54.996 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.043 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.044 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.045 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.048 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.063 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.071 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.816 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.819 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.820 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.887 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:55.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.074 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.079 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.082 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.084 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.162 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.163 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.165 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.167 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.170 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.173 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.176 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.181 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.182 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.346 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.350 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.355 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:56.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:57.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:57.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:57.955 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:57.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:57.958 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:57.959 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.067 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.072 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.075 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.077 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.080 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.088 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.091 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-08 23:18:58.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# False
