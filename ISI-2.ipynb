# %%
import streamlit as st
import pandas as pd
import plotly.express as px

# Set up Streamlit page
st.set_page_config(page_title="Election Dashboard", layout="wide")
st.title("🗳️ Election Dashboard")

# Load data
@st.cache_data
def load_data():
    df = pd.read_excel("D:/District-Trend.xlsx", sheet_name=None)
    return df

data_dict = load_data()

# Sidebar filters
st.sidebar.header("📌 Filter Options")
constituencies = list(data_dict.keys())
selected_ac = st.sidebar.selectbox("Select Constituency", constituencies)

# Prepare the data
raw_df = data_dict[selected_ac]
raw_df = raw_df.dropna(how='all').dropna(axis=1, how='all')

# Melt data into long format
df_long = raw_df.melt(id_vars=[raw_df.columns[0]], var_name="Party-Year", value_name="VoteShare")
df_long[['Party', 'Year']] = df_long['Party-Year'].astype(str).str.extract(r'(.+)-(\d+)', expand=True)
df_long['Year'] = pd.to_numeric(df_long['Year'], errors='coerce')
df_long['VoteShare'] = pd.to_numeric(df_long['VoteShare'], errors='coerce')
df_long = df_long.dropna(subset=['VoteShare'])

# Party selector
party_options = sorted(df_long['Party'].dropna().unique())
selected_party = st.sidebar.selectbox("Select Party", party_options)
party_df = df_long[df_long['Party'] == selected_party]

# Line chart
st.subheader(f"📈 Vote Share Over Time for {selected_party} in {selected_ac}")
fig_line = px.line(party_df, x='Year', y='VoteShare', title="Vote Share Trend", markers=True)
st.plotly_chart(fig_line, use_container_width=True)

# Histogram
st.subheader(f"📊 Vote Share Histogram for {selected_party}")
fig_hist = px.histogram(party_df, x='VoteShare', nbins=10, title="Vote Share Distribution")
st.plotly_chart(fig_hist, use_container_width=True)

# Winner by year
st.subheader(f"🏆 Yearly Winner in {selected_ac}")
winner_df = df_long.groupby(['Year', 'Party'])['VoteShare'].sum().reset_index()
winner_idx = winner_df.groupby('Year')['VoteShare'].idxmax()
winner_table = winner_df.loc[winner_idx].sort_values('Year')
st.dataframe(winner_table.reset_index(drop=True))

# Raw data
with st.expander("🔍 View Raw Data"):
    st.dataframe(df_long)
# Out:
# 2025-07-09 00:37:01.714 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:01.730 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:01.731 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:01.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:01.752 No runtime found, using MemoryCacheStorageManager
# 2025-07-09 00:37:01.771 No runtime found, using MemoryCacheStorageManager
# 2025-07-09 00:37:01.800 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:01.803 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:01.808 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:01.817 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:02.448 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:02.487 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:02.496 Thread 'Thread-4': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.113 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.118 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.194 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.201 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.204 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.207 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.358 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.360 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.361 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.371 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.373 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.491 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.493 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.494 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.495 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.497 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.499 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.500 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.501 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.787 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.789 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.790 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.791 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.793 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.957 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.960 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:06.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:07.000 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-07-09 00:37:07.002 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
